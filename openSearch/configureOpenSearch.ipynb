# %%
from opensearchpy import OpenSearch

# %%
#Initialize connection to opensearch
host = 'localhost'
port = 9200
auth = ('admin', 'admin') 

client = OpenSearch(
    hosts = [{'host': host, 'port': port}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = False,
    timeout=100
)
#check status
print(client.info())
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'name': 'opensearch-node1', 'cluster_name': 'opensearch-cluster', 'cluster_uuid': 'nWznQVwDRy-Rrj0Ugyk__Q', 'version': {'distribution': 'opensearch', 'number': '2.11.1', 'build_type': 'tar', 'build_hash': '6b1986e964d440be9137eba1413015c31c5a7752', 'build_date': '2023-11-29T21:43:10.135035992Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.10.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'The OpenSearch Project: https://opensearch.org/'}

# %%
#create VectorDB index:

index_name = "wmt_financial_e5_512"
index_body = {
    "settings": {
    "index": {
      "knn": True,
      "knn.algo_param.ef_search": 100
    }
  },
  "mappings": {
    "properties": {
        "vector": {
          "type": "knn_vector",
          "dimension": 1024,     #Thats the output dimension of the e5 model
          "method": {
            "name": "hnsw",
            "space_type": "cosinesimil",
            "engine": "nmslib",
            "parameters": {
              "ef_construction": 512,
              "m": 24
            }
          }
        }
    }
  }
}

response = client.indices.create(index_name, body = index_body)
print(response)
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'wmt_financial_e5_512'}

# %%
import csv

loaded_list_of_lists = []

# Read the CSV file and load it into a list of lists
with open('../data/embeddings/embeddings_3.csv', 'r') as file:
    reader = csv.reader(file)
    loaded_list_of_lists = [row for row in reader]

# %%
for chunk in loaded_list_of_lists:
    chunk[0] = eval(chunk[0])

# %%
print(loaded_list_of_lists[0])
# Out:
# [[-0.00016050208068918437, -0.0225758608430624, 0.011367831379175186, -0.021035796031355858, -0.04042990878224373, 0.024891795590519905, -0.06107403710484505, -0.04026772454380989, -0.03388090431690216, 0.012928882613778114, 0.031399328261613846, -0.017383959144353867, 0.04096107929944992, 0.031691115349531174, 0.03828968480229378, 0.025142256170511246, -0.015011095441877842, -0.012760070152580738, 0.0613536611199379, -0.05611129105091095, 0.039570827037096024, -0.045836418867111206, -0.03392574563622475, 0.003746081842109561, 0.0009654692839831114, -0.03735732659697533, -0.004992614034563303, -0.01590718887746334, -0.03253298997879028, 0.012206889688968658, -0.020696306601166725, -0.008061053231358528, 0.04077144339680672, -0.002242524642497301, 0.03209373727440834, 0.013896296732127666, -0.053449537605047226, -0.052630726248025894, 0.03315321356058121, 0.019637294113636017, -0.02626550942659378, 0.04514243081212044, -0.025280628353357315, 0.05744270980358124, 0.02571248821914196, -0.016349337995052338, -0.035540275275707245, 0.014293220825493336, 0.01188400574028492, -0.011385300196707249, 0.04190485179424286, -0.03528769686818123, 0.0371147021651268, 0.029313713312149048, -0.013349398039281368, 0.035782359540462494, 0.01453255396336317, 0.04718828201293945, -0.024822846055030823, -0.004289156291633844, 0.01612081192433834, -0.008737140335142612, 0.038244664669036865, -0.04669956490397453, 0.04682063311338425, -0.048384346067905426, 0.031045306473970413, 0.040713731199502945, 0.016917714849114418, -0.014058574102818966, -0.0388585664331913, -0.0732368603348732, 0.01494715828448534, 0.048127830028533936, 0.054512232542037964, -0.04147360846400261, -0.019785750657320023, 0.042517758905887604, 0.021247483789920807, 0.06530237942934036, -0.040581293404102325, -0.02377997897565365, -0.021781813353300095, -0.03819804638624191, -0.009627222083508968, -0.006436492782086134, 0.016226349398493767, -0.014811702072620392, 0.046140722930431366, 0.024438457563519478, 0.014888002537190914, -0.024381345137953758, 0.04187565669417381, 0.01472990121692419, -0.04539521411061287, 0.0014472873881459236, -0.04608403891324997, 0.026322122663259506, -0.0008731410489417613, -0.02664771117269993, -0.013095500878989697, -0.04025993496179581, -0.015324818901717663, 0.034479476511478424, -0.01641612872481346, 0.029304837808012962, -0.039566874504089355, 0.01508708018809557, -0.04363814368844032, -0.005127802025526762, 0.006310500204563141, 0.0032334441784769297, -0.01811339147388935, 0.0011519499821588397, -0.03785618022084236, 0.04752327874302864, 0.005534231197088957, -0.023168765008449554, 0.005637012422084808, 0.005476820282638073, 0.054857850074768066, 0.041333120316267014, -0.0317232683300972, -0.013198691420257092, -0.03377190977334976, 0.04641135409474373, -0.01935523934662342, -0.017450861632823944, 0.03248784318566322, 0.04715198650956154, -0.0005868926527909935, -0.034485023468732834, 0.016382655128836632, -0.0061096930876374245, 0.004182643257081509, 0.07548931986093521, -0.025769801810383797, -0.062498077750205994, 0.029734505340456963, 0.05095813795924187, -0.040346503257751465, -0.06721629947423935, 0.03420064598321915, 0.02626112475991249, 0.02078614942729473, -0.030151162296533585, -0.021386511623859406, -0.04909246042370796, -0.05632960796356201, -0.033397696912288666, -0.040960438549518585, -0.003958110697567463, -0.04317685216665268, -0.0032261277083307505, 0.021015457808971405, -0.03158470615744591, -0.013495858758687973, -0.019062411040067673, -0.02346322312951088, 0.037645142525434494, 0.035018760710954666, 0.03409517928957939, -0.007293797098100185, 0.006649847608059645, 0.03854222968220711, -0.014549934305250645, 0.031842272728681564, 0.0172320194542408, -0.004788032732903957, 0.016205260530114174, 0.020165571942925453, 0.034992314875125885, 0.04402441531419754, 0.023167219012975693, 0.013319683261215687, -0.004982679150998592, 0.03732392191886902, -0.05282507836818695, 0.01599629409611225, 0.02186480723321438, -0.01652351208031 ...

# %%
def divide_list(input_list, n):
    chunk_size = len(input_list) // n
    remainder = len(input_list) % n

    start = 0
    result = []

    for i in range(n):
        end = start + chunk_size + (1 if i < remainder else 0)
        result.append(input_list[start:end])
        start = end

    return result

# %%
result = divide_list(loaded_list_of_lists, 20)

# %%
print(len(result[10]))
# Out:
# 63

# %%
print(len(result[0]))
from tqdm import tqdm
data_for_bulk_insert = []

for batch in tqdm(result):
    for chunk in batch:
        data_for_bulk_insert.append({"index": {"_index": index_name, "_id": chunk[3]}})
        data_for_bulk_insert.append({"vector" : chunk[0], "text" : chunk[1], "year": chunk[2]})
    response = client.bulk(data_for_bulk_insert)
    data_for_bulk_insert = []
# Out:
# 64
#   0%|          | 0/20 [00:00<?, ?it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#   5%|▌         | 1/20 [00:00<00:17,  1.08it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  10%|█         | 2/20 [00:01<00:12,  1.45it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  15%|█▌        | 3/20 [00:01<00:10,  1.69it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  20%|██        | 4/20 [00:02<00:08,  1.98it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  25%|██▌       | 5/20 [00:02<00:06,  2.35it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  30%|███       | 6/20 [00:02<00:05,  2.55it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  35%|███▌      | 7/20 [00:03<00:04,  2.67it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  40%|████      | 8/20 [00:03<00:04,  2.77it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  45%|████▌     | 9/20 [00:03<00:03,  3.03it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  50%|█████     | 10/20 [00:04<00:03,  3.24it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  55%|█████▌    | 11/20 [00:04<00:02,  3.43it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  60%|██████    | 12/20 [00:04<00:02,  3.58it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  65%|██████▌   | 13/20 [00:04<00:01,  3.70it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  70%|███████   | 14/20 [00:05<00:01,  3.75it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  75%|███████▌  | 15/20 [00:05<00:01,  3.88it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  80%|████████  | 16/20 [00:05<00:01,  3.83it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  85%|████████▌ | 17/20 [00:05<00:00,  3.82it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  90%|█████████ | 18/20 [00:06<00:00,  3.96it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#  95%|█████████▌| 19/20 [00:06<00:00,  3.95it/s]C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 100%|██████████| 20/20 [00:06<00:00,  3.03it/s]
